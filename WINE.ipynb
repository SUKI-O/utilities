# %% [markdown]
# <a href="https://colab.research.google.com/github/SUKI-O/utilities/blob/master/WINE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import itertools

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

def test_loop(test_cases):
    
    success = 0
    fails = 0
    
    for test_case in test_cases:
        try:
            assert test_case["result"] == test_case["expected"]
            success += 1
    
        except:
            fails += 1
            print(f'{test_case["name"]}: {test_case["error_message"]}\nExpected: {test_case["expected"]}\nResult: {test_case["result"]}\nPlease open utils.py if you want to see the unit test here.\n')

    if fails == 0:
        print("\033[92m All public tests passed")

    else:
        print('\033[92m', success," Tests passed")
        print('\033[91m', fails, " Tests failed")
        raise Exception(test_case["error_message"])
        
def test_white_df(white_df):
    
    test_cases = [
        {
            "name": "type_check",
            "result": type(white_df.is_red[0]),
            "expected": np.int64,
            "error_message": f'white_df.is_red has an incorrect type.'
        },
        {
            "name": "output_check",
            "result": white_df.is_red[0],
            "expected": 0,
            "error_message": "white_df.is_red is not set correctly"
        },
        {
            "name": "len_check",
            "result": len(white_df),
            "expected": 3961,
            "error_message": "Number of rows is incorrect. Please drop duplicates."
        }
    ]
    
    test_loop(test_cases)
    
def test_red_df(red_df):
    
    test_cases = [
        {
            "name": "type_check",
            "result": type(red_df.is_red[0]),
            "expected": np.int64,
            "error_message": f'red_df.is_red has an incorrect type.'
        },
        {
            "name": "output_check",
            "result": red_df.is_red[0],
            "expected": 1,
            "error_message": "red_df.is_red is not set correctly"
        },
        {
            "name": "len_check",
            "result": len(red_df),
            "expected": 1359,
            "error_message": "Number of rows is incorrect. Please drop duplicates."
        }
    ]
    
    test_loop(test_cases)
    
def test_df_drop(df):
    
    test_cases = [
        {
            "name": "df.alcohol[0]_check",
            "result": df.alcohol[0],
            "expected": 9.4,
            "error_message": f'Value is not as expected. Please check quality interval.'
        },
        {
            "name": "df.alcohol[100]_check",
            "result": df.alcohol[100],
            "expected": 10.9,
            "error_message": f'Value is not as expected. Please check quality interval.'
        }
    ]
    
    test_loop(test_cases)

def test_data_sizes(train_size, test_size, val_size):
    
    test_cases = [
        {
            "name": "train_test_size_check",
            "result": train_size > test_size,
            "expected": True,
            "error_message": f'train.size is too small. Please check implementation.'
        },
        {
            "name": "train_val_size_check",
            "result": train_size > val_size,
            "expected": True,
            "error_message": f'train.size is too small. Please check implementation.'
        },
        {
            "name": "test_val_size_check",
            "result": test_size > val_size,
            "expected": True,
            "error_message": f'test.size is too small. Please check implementation.'
        }
    ]
    
    test_loop(test_cases)

def test_format_output(df, train_Y, val_Y, test_Y):
    
    train, test = train_test_split(df, test_size=0.2, random_state=1)
    train, val = train_test_split(train, test_size=0.2, random_state=1)
    
    test_cases = [
        {
            "name": "train_Y[0]_check",
            "result": np.all(train_Y[0] == np.array(train.quality)),
            "expected": True,
            "error_message": f'train_Y[0] is not equal to train.quality. Please check implementation.'
        },
        {
            "name": "train_Y[1]_check",
            "result": np.all(train_Y[1] == np.array(train.is_red)),
            "expected": True,
            "error_message": f'train_Y[1] is not equal to train.is_red. Please check implementation.'
        },
        {
            "name": "val_Y[0]_check",
            "result": np.all(val_Y[0] == np.array(val.quality)),
            "expected": True,
            "error_message": f'train_Y[0] is not equal to val.quality. Please check implementation.'
        },
        {
            "name": "val_Y[1]_check",
            "result": np.all(val_Y[1] == np.array(val.is_red)),
            "expected": True,
            "error_message": f'train_Y[1] is not equal to val.is_red. Please check implementation.'
        },
        {
            "name": "test_Y[0]_check",
            "result": np.all(test_Y[0] == np.array(test.quality)),
            "expected": True,
            "error_message": f'test_Y[0] is not equal to test.quality. Please check implementation.'
        },
        {
            "name": "test_Y[1]_check",
            "result": np.all(test_Y[1] == np.array(test.is_red)),
            "expected": True,
            "error_message": f'test_Y[1] is not equal to test.is_red. Please check implementation.'
        }
    ]
    
    test_loop(test_cases)

def test_norm(norm_train_X, norm_val_X, norm_test_X, train, val, test):
    
    from pandas.core.frame import DataFrame
    
    test_cases = [
        {
            "name": "norm_train_X_type_check",
            "result": type(norm_train_X),
            "expected": DataFrame,
            "error_message": f'norm_train_X has an incorrect type.'
        },
        {
            "name": "norm_val_X_type_check",
            "result": type(norm_val_X),
            "expected": DataFrame,
            "error_message": f'norm_val_X has an incorrect type.'
        },
        {
            "name": "norm_test_X_type_check",
            "result": type(norm_test_X),
            "expected": DataFrame,
            "error_message": f'norm_test_X has an incorrect type.'
        },
        {
            "name": "norm_train_X_length_check",
            "result": len(norm_train_X),
            "expected": len(train),
            "error_message": f'norm_train_X has an incorrect length.'
        },
        {
            "name": "norm_val_X_length_check",
            "result": len(norm_val_X),
            "expected": len(val),
            "error_message": f'norm_val_X has an incorrect length.'
        },
        {
            "name": "norm_test_X_length_check",
            "result": len(norm_test_X),
            "expected": len(test),
            "error_message": f'norm_test_X has an incorrect length.'
        },
    ]
    
    test_loop(test_cases)

def test_base_model(base_model):
    
    test_inputs = tf.keras.layers.Input(shape=(11,))
    test_output = base_model(test_inputs)
    test_model = Model(inputs=test_inputs, outputs=test_output)

    test_cases = [
        {
            "name": "return_type_check",
            "result": type(test_output),
            "expected": tf.Tensor,
            "error_message": 'Return type is incorrect. Please check implementation.'
        },
        {
            "name": "return_shape_check",
            "result": str(test_output.shape),
            "expected": '(None, 128)',
            "error_message": 'Return shape is incorrect. Please check implementation.'
        },
        {
            "name": "tensor_dtype_check",
            "result": str(test_output.dtype),
            "expected": "<dtype: 'float32'>",
            "error_message": 'model dtype is incorrect. Please check implementation.'
        },
        {
            "name": "base_model_num_layers_check",
            "result": len(test_model.layers),
            "expected": 3,
            "error_message": 'There are too many layers. Please check implementation.'
        },
        {
            "name": "base_model_layer1_check",
            "result": type(test_model.layers[-2]),
            "expected": Dense,
            "error_message": 'First layer type is incorrect. Please check implementation.'
        },
        {
            "name": "base_model_layer2_check",
            "result": type(test_model.layers[-1]),
            "expected": Dense,
            "error_message": 'Output layer type is incorrect. Please check implementation.'
        },
    ]
    
    test_loop(test_cases)

def test_final_model(final_model):
    
    test_inputs = tf.keras.layers.Input(shape=(11,))
    test_output = final_model(test_inputs)

    test_cases = [
        {
            "name": "return_type_check",
            "result": type(test_output),
            "expected": tf.keras.Model,
            "error_message": 'Return type is incorrect. Please check implementation.'
        },
        {
            "name": "layer_3_activation_check",
            "result": test_output.layers[4].activation,
            "expected": tf.keras.activations.sigmoid,
            "error_message": 'wine_quality layer has an incorrect activation. Please check implementation.'
        },
    ]
    
    test_loop(test_cases)
    
def test_model_compile(model):

    from tensorflow.python.keras.metrics import MeanMetricWrapper

    test_cases = [
        {
            "name": "metrics_0_check",
            "result": type(model.metrics[0]),
            "expected": tf.keras.metrics.RootMeanSquaredError,
            "error_message": 'wine quality metrics is incorrect. Please check implementation.'
        },
        {
            "name": "metrics_1_check",
            "result": (model.metrics[1].name == 'wine_type_accuracy') or 
                      (model.metrics[1].name == 'wine_type_binary_accuracy'),
            "expected": True,
            "error_message": f'wine type metrics: {model.metrics[1].name} is incorrect. Please check implementation.'
        },
        {
            "name": "wine_type_loss_check",
            "result": (model.loss['wine_type'] == 'binary_crossentropy') or 
                      (model.loss['wine_type'].name == 'binary_crossentropy') or 
                      (str(model.loss['wine_type']).split()[1] == 'binary_crossentropy'),
            "expected": True,
            "error_message": f'wine type loss: {model.loss["wine_type"]} is incorrect. Please check implementation.'
        },
        {
            "name": "wine_quality_loss_check",
            "result": (model.loss['wine_quality'] in ['mse', 'mean_squared_error']) or 
                      (str(model.loss['wine_quality']).split()[1] == 'mean_squared_error') or 
                      (model.loss['wine_quality'].name == 'mean_squared_error'),
            "expected": True,
            "error_message": f'wine quality loss: {model.loss["wine_type"]} is incorrect. Please check implementation.'
        },
    ]
    
    test_loop(test_cases)
    
def test_history(history):

    vars_history = vars(history)
    
    test_cases = [
        {
            "name": "type_check",
            "result": type(history),
            "expected": tf.keras.callbacks.History,
            "error_message": 'history type is incorrect. Please check model.fit().'
        },
        {
            "name": "params_samples_check",
            "result": vars_history['params']['samples'],
            "expected": 3155,
            "error_message": 'Training samples is incorrect. Please check arguments to model.fit().'
        },
        {
            "name": "params_do_validation_check",
            "result": vars_history['params']['do_validation'],
            "expected": True,
            "error_message": 'No validation data is present. Please check arguments to model.fit().'
        },
    ]
    
    test_loop(test_cases)

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# URL of the white wine dataset
URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv'

# load the dataset from the URL
white_df = pd.read_csv(URL, sep=";")

# fill the `is_red` column with zeros.
white_df["is_red"] = np.zeros(white_df.shape[0])

# keep only the first of duplicate items
white_df = white_df.drop_duplicates(keep='first')

# %%
# URL of the red wine dataset
URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv'

# load the dataset from the URL
red_df = pd.read_csv(URL, sep=";")

# fill the `is_red` column with ones.
red_df["is_red"] = np.repeat(1, len(red_df))

# keep only the first of duplicate items
red_df = red_df.drop_duplicates(keep='first')

# %%
df = pd.concat([red_df, white_df], ignore_index=True)

# %%
# get data with wine quality greater than 4 and less than 8
df = df[(df['quality'] > 4) & (df['quality'] < 8)]

# reset index and drop the old one
df = df.reset_index(drop=True)

# %%
df['quality'].hist(bins=20);

# %%
# Please uncomment all lines in this cell and replace those marked with `# YOUR CODE HERE`.
# You can select all lines in this code cell with Ctrl+A (Windows/Linux) or Cmd+A (Mac), then press Ctrl+/ (Windows/Linux) or Cmd+/ (Mac) to uncomment.



# Please do not change the random_state parameter. This is needed for grading.

# split df into 80:20 train and test sets
train, test = train_test_split(df, test_size=0.2, random_state = 1)
                               
# split train into 80:20 train and val sets
train, val = train_test_split(train, test_size=0.2, random_state = 1)

# %%
train_stats = train.describe()
train_stats.pop('is_red')
train_stats.pop('quality')
train_stats = train_stats.transpose()
train_stats
# Out:
#                        count        mean  ...       75%        max
# fixed acidity         3155.0    7.221616  ...    7.7000   15.60000
# volatile acidity      3155.0    0.338929  ...    0.4000    1.24000
# citric acid           3155.0    0.321569  ...    0.4000    1.66000
# residual sugar        3155.0    5.155911  ...    7.6500   65.80000
# chlorides             3155.0    0.056976  ...    0.0660    0.61100
# free sulfur dioxide   3155.0   30.388590  ...   41.0000  131.00000
# total sulfur dioxide  3155.0  115.062282  ...  156.0000  344.00000
# density               3155.0    0.994633  ...    0.9968    1.03898
# pH                    3155.0    3.223201  ...    3.3300    4.01000
# sulphates             3155.0    0.534051  ...    0.6000    1.95000
# alcohol               3155.0   10.504466  ...   11.3000   14.00000
#
# [11 rows x 8 columns]

# %%
def format_output(data):
    is_red = data.pop('is_red')
    is_red = np.array(is_red)
    quality = data.pop('quality')
    quality = np.array(quality)
    return (quality, is_red)

# %%
# format the output of the train set
train_Y = format_output(train)

# format the output of the val set
val_Y = format_output(val)
    
# format the output of the test set
test_Y = format_output(test)

# %%
train.head()
# Out:
#       fixed acidity  volatile acidity  citric acid  ...    pH  sulphates  alcohol
# 225             7.5              0.65         0.18  ...  3.38       0.77      9.4
# 3557            6.3              0.27         0.29  ...  3.14       0.40      8.8
# 3825            8.8              0.27         0.25  ...  2.87       0.49     11.4
# 1740            6.4              0.45         0.07  ...  2.97       0.28     10.8
# 1221            7.2              0.53         0.13  ...  3.21       0.68      9.9
#
# [5 rows x 11 columns]

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']

# %%
# normalize the train set
norm_train_X = norm(train)
    
# normalize the val set
norm_val_X = norm(val)
    
# normalize the test set
norm_test_X = norm(test)

# %%
def base_model(inputs):
    
    # connect a Dense layer with 128 neurons and a relu activation
    x = Dense(128, activation="relu")(inputs)
    
    # connect another Dense layer with 128 neurons and a relu activation
    x = Dense(128, activation="relu")(x)
    return x

# %%
def final_model(inputs):
    
    # get the base model
    x = base_model(inputs)

    # connect the output Dense layer for regression
    wine_quality = Dense(units='1', name='wine_quality')(x)

    # connect the output Dense layer for classification. this will use a sigmoid activation.
    wine_type = Dense(units='1', activation='sigmoid', name='wine_type')(x)

    # define the model using the input and output layers
    model = Model(inputs=inputs, outputs=[wine_quality, wine_type])

    return model

# %%
inputs = tf.keras.layers.Input(shape=(11,))
rms = tf.keras.optimizers.RMSprop(lr=0.0001)
model = final_model(inputs)

model.compile(optimizer=rms, 
              loss = {'wine_type' : 'binary_crossentropy',
                      'wine_quality' : 'mse'
                     },
              metrics = {'wine_type' : 'accuracy',
                         'wine_quality': tf.keras.metrics.RootMeanSquaredError()
                       }
             )

# %%
history = model.fit(norm_train_X, train_Y,
                    epochs = 180, validation_data=(norm_test_X, test_Y))
# Out:
# Epoch 1/180
# 99/99 [==============================] - 2s 6ms/step - loss: 30.9232 - wine_quality_loss: 30.1982 - wine_type_loss: 0.7249 - wine_quality_root_mean_squared_error: 5.4911 - wine_type_accuracy: 0.3561 - val_loss: 20.0624 - val_wine_quality_loss: 19.3281 - val_wine_type_loss: 0.7343 - val_wine_quality_root_mean_squared_error: 4.3964 - val_wine_type_accuracy: 0.3445
# Epoch 2/180
# 99/99 [==============================] - 0s 2ms/step - loss: 16.4996 - wine_quality_loss: 15.7598 - wine_type_loss: 0.7397 - wine_quality_root_mean_squared_error: 3.9635 - wine_type_accuracy: 0.3325 - val_loss: 8.5413 - val_wine_quality_loss: 7.8277 - val_wine_type_loss: 0.7136 - val_wine_quality_root_mean_squared_error: 2.7978 - val_wine_type_accuracy: 0.4732
# Epoch 3/180
# 99/99 [==============================] - 0s 3ms/step - loss: 6.5985 - wine_quality_loss: 5.9128 - wine_type_loss: 0.6857 - wine_quality_root_mean_squared_error: 2.4246 - wine_type_accuracy: 0.5563 - val_loss: 3.5883 - val_wine_quality_loss: 2.9978 - val_wine_type_loss: 0.5905 - val_wine_quality_root_mean_squared_error: 1.7314 - val_wine_type_accuracy: 0.7619
# Epoch 4/180
# 99/99 [==============================] - 0s 3ms/step - loss: 3.0747 - wine_quality_loss: 2.5332 - wine_type_loss: 0.5415 - wine_quality_root_mean_squared_error: 1.5909 - wine_type_accuracy: 0.7992 - val_loss: 2.6392 - val_wine_quality_loss: 2.2017 - val_wine_type_loss: 0.4374 - val_wine_quality_root_mean_squared_error: 1.4838 - val_wine_type_accuracy: 0.8085
# Epoch 5/180
# 99/99 [==============================] - 0s 4ms/step - loss: 2.4335 - wine_quality_loss: 2.0407 - wine_type_loss: 0.3927 - wine_quality_root_mean_squared_error: 1.4271 - wine_type_accuracy: 0.8346 - val_loss: 2.2256 - val_wine_quality_loss: 1.8965 - val_wine_type_loss: 0.3291 - val_wine_quality_root_mean_squared_error: 1.3771 - val_wine_type_accuracy: 0.9017
# Epoch 6/180
# 99/99 [==============================] - 0s 2ms/step - loss: 2.0450 - wine_quality_loss: 1.7442 - wine_type_loss: 0.3008 - wine_quality_root_mean_squared_error: 1.3193 - wine_type_accuracy: 0.9281 - val_loss: 1.9361 - val_wine_quality_loss: 1.6861 - val_wine_type_loss: 0.2500 - val_wine_quality_root_mean_squared_error: 1.2985 - val_wine_type_accuracy: 0.9726
# Epoch 7/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.7552 - wine_quality_loss: 1.5209 - wine_type_loss: 0.2343 - wine_quality_root_mean_squared_error: 1.2325 - wine_type_accuracy: 0.9723 - val_loss: 1.7383 - val_wine_quality_loss: 1.5461 - val_wine_type_loss: 0.1922 - val_wine_quality_root_mean_squared_error: 1.2434 - val_wine_type_accuracy: 0.9878
# Epoch 8/180
# 99/99 [==============================] - 0s 3ms/step - loss: 1.6615 - wine_quality_loss: 1.4847 - wine_type_loss: 0.1768 - wine_quality_root_mean_squared_error: 1.2182 - wine_type_accuracy: 0.9862 - val_loss: 1.5793 - val_wine_quality_loss: 1.4291 - val_wine_type_loss: 0.1502 - val_wine_quality_root_mean_squared_error: 1.1955 - val_wine_type_accuracy: 0.9868
# Epoch 9/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.5946 - wine_quality_loss: 1.4613 - wine_type_loss: 0.1333 - wine_quality_root_mean_squared_error: 1.2076 - wine_type_accuracy: 0.9878 - val_loss: 1.4532 - val_wine_quality_loss: 1.3320 - val_wine_type_loss: 0.1212 - val_wine_quality_root_mean_squared_error: 1.1541 - val_wine_type_accuracy: 0.9889
# Epoch 10/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.3405 - wine_quality_loss: 1.2273 - wine_type_loss: 0.1132 - wine_quality_root_mean_squared_error: 1.1074 - wine_type_accuracy: 0.9920 - val_loss: 1.3466 - val_wine_quality_loss: 1.2464 - val_wine_type_loss: 0.1002 - val_wine_quality_root_mean_squared_error: 1.1164 - val_wine_type_accuracy: 0.9919
# Epoch 11/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.2350 - wine_quality_loss: 1.1454 - wine_type_loss: 0.0896 - wine_quality_root_mean_squared_error: 1.0700 - wine_type_accuracy: 0.9919 - val_loss: 1.2402 - val_wine_quality_loss: 1.1549 - val_wine_type_loss: 0.0853 - val_wine_quality_root_mean_squared_error: 1.0747 - val_wine_type_accuracy: 0.9909
# Epoch 12/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.1008 - wine_quality_loss: 1.0237 - wine_type_loss: 0.0771 - wine_quality_root_mean_squared_error: 1.0112 - wine_type_accuracy: 0.9912 - val_loss: 1.1597 - val_wine_quality_loss: 1.0848 - val_wine_type_loss: 0.0749 - val_wine_quality_root_mean_squared_error: 1.0416 - val_wine_type_accuracy: 0.9899
# Epoch 13/180
# 99/99 [==============================] - 0s 2ms/step - loss: 1.1187 - wine_quality_loss: 1.0432 - wine_type_loss: 0.0755 - wine_quality_root_mean_squared_error: 1.0202 - wine_type_accuracy: 0.9905 - val_loss: 1.0898 - val_wine_quality_loss: 1.0227 - val_wine_type_loss: 0.0672 - val_wine_quality_root_mean_squared_error: 1.0113 - val_wine_type_accuracy: 0.9909
# Epoch 14/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.9977 - wine_quality_loss: 0.9377 - wine_type_loss: 0.0601 - wine_quality_root_mean_squared_error: 0.9681 - wine_type_accuracy: 0.9901 - val_loss: 1.0263 - val_wine_quality_loss: 0.9650 - val_wine_type_loss: 0.0613 - val_wine_quality_root_mean_squared_error: 0.9823 - val_wine_type_accuracy: 0.9919
# Epoch 15/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.9441 - wine_quality_loss: 0.8812 - wine_type_loss: 0.0629 - wine_quality_root_mean_squared_error: 0.9384 - wine_type_accuracy: 0.9907 - val_loss: 0.9639 - val_wine_quality_loss: 0.9071 - val_wine_type_loss: 0.0568 - val_wine_quality_root_mean_squared_error: 0.9524 - val_wine_type_accuracy: 0.9919
# Epoch 16/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.8751 - wine_quality_loss: 0.8215 - wine_type_loss: 0.0535 - wine_quality_root_mean_squared_error: 0.9055 - wine_type_accuracy: 0.9925 - val_loss: 0.9047 - val_wine_quality_loss: 0.8514 - val_wine_type_loss: 0.0533 - val_wine_quality_root_mean_squared_error: 0.9227 - val_wine_type_accuracy: 0.9919
# Epoch 17/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.8713 - wine_quality_loss: 0.8144 - wine_type_loss: 0.0569 - wine_quality_root_mean_squared_error: 0.9020 - wine_type_accuracy: 0.9910 - val_loss: 0.8572 - val_wine_quality_loss: 0.8064 - val_wine_type_loss: 0.0507 - val_wine_quality_root_mean_squared_error: 0.8980 - val_wine_type_accuracy: 0.9919
# Epoch 18/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.7916 - wine_quality_loss: 0.7326 - wine_type_loss: 0.0589 - wine_quality_root_mean_squared_error: 0.8558 - wine_type_accuracy: 0.9931 - val_loss: 0.8145 - val_wine_quality_loss: 0.7661 - val_wine_type_loss: 0.0483 - val_wine_quality_root_mean_squared_error: 0.8753 - val_wine_type_accuracy: 0.9919
# Epoch 19/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.8907 - wine_quality_loss: 0.8457 - wine_type_loss: 0.0450 - wine_quality_root_mean_squared_error: 0.9102 - wine_type_accuracy: 0.9917 - val_loss: 0.7884 - val_wine_quality_loss: 0.7420 - val_wine_type_loss: 0.0464 - val_wine_quality_root_mean_squared_error: 0.8614 - val_wine_type_accuracy: 0.9919
# Epoch 20/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.6960 - wine_quality_loss: 0.6533 - wine_type_loss: 0.0427 - wine_quality_root_mean_squared_error: 0.8078 - wine_type_accuracy: 0.9923 - val_loss: 0.7438 - val_wine_quality_loss: 0.6989 - val_wine_type_loss: 0.0449 - val_wine_quality_root_mean_squared_error: 0.8360 - val_wine_type_accuracy: 0.9919
# Epoch 21/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.7009 - wine_quality_loss: 0.6526 - wine_type_loss: 0.0483 - wine_quality_root_mean_squared_error: 0.8074 - wine_type_accuracy: 0.9930 - val_loss: 0.7090 - val_wine_quality_loss: 0.6654 - val_wine_type_loss: 0.0437 - val_wine_quality_root_mean_squared_error: 0.8157 - val_wine_type_accuracy: 0.9919
# Epoch 22/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.6609 - wine_quality_loss: 0.6169 - wine_type_loss: 0.0441 - wine_quality_root_mean_squared_error: 0.7852 - wine_type_accuracy: 0.9919 - val_loss: 0.6811 - val_wine_quality_loss: 0.6385 - val_wine_type_loss: 0.0426 - val_wine_quality_root_mean_squared_error: 0.7991 - val_wine_type_accuracy: 0.9929
# Epoch 23/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.6044 - wine_quality_loss: 0.5643 - wine_type_loss: 0.0401 - wine_quality_root_mean_squared_error: 0.7509 - wine_type_accuracy: 0.9934 - val_loss: 0.6483 - val_wine_quality_loss: 0.6067 - val_wine_type_loss: 0.0416 - val_wine_quality_root_mean_squared_error: 0.7789 - val_wine_type_accuracy: 0.9929
# Epoch 24/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5821 - wine_quality_loss: 0.5481 - wine_type_loss: 0.0341 - wine_quality_root_mean_squared_error: 0.7401 - wine_type_accuracy: 0.9951 - val_loss: 0.6367 - val_wine_quality_loss: 0.5959 - val_wine_type_loss: 0.0409 - val_wine_quality_root_mean_squared_error: 0.7719 - val_wine_type_accuracy: 0.9929
# Epoch 25/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5759 - wine_quality_loss: 0.5321 - wine_type_loss: 0.0439 - wine_quality_root_mean_squared_error: 0.7294 - wine_type_accuracy: 0.9909 - val_loss: 0.6025 - val_wine_quality_loss: 0.5624 - val_wine_type_loss: 0.0401 - val_wine_quality_root_mean_squared_error: 0.7499 - val_wine_type_accuracy: 0.9929
# Epoch 26/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5802 - wine_quality_loss: 0.5420 - wine_type_loss: 0.0382 - wine_quality_root_mean_squared_error: 0.7359 - wine_type_accuracy: 0.9934 - val_loss: 0.5862 - val_wine_quality_loss: 0.5467 - val_wine_type_loss: 0.0395 - val_wine_quality_root_mean_squared_error: 0.7394 - val_wine_type_accuracy: 0.9929
# Epoch 27/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5461 - wine_quality_loss: 0.5097 - wine_type_loss: 0.0364 - wine_quality_root_mean_squared_error: 0.7137 - wine_type_accuracy: 0.9931 - val_loss: 0.5560 - val_wine_quality_loss: 0.5171 - val_wine_type_loss: 0.0389 - val_wine_quality_root_mean_squared_error: 0.7191 - val_wine_type_accuracy: 0.9939
# Epoch 28/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.5270 - wine_quality_loss: 0.4910 - wine_type_loss: 0.0359 - wine_quality_root_mean_squared_error: 0.7006 - wine_type_accuracy: 0.9952 - val_loss: 0.5342 - val_wine_quality_loss: 0.4958 - val_wine_type_loss: 0.0384 - val_wine_quality_root_mean_squared_error: 0.7041 - val_wine_type_accuracy: 0.9939
# Epoch 29/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4900 - wine_quality_loss: 0.4530 - wine_type_loss: 0.0371 - wine_quality_root_mean_squared_error: 0.6728 - wine_type_accuracy: 0.9937 - val_loss: 0.5200 - val_wine_quality_loss: 0.4820 - val_wine_type_loss: 0.0379 - val_wine_quality_root_mean_squared_error: 0.6943 - val_wine_type_accuracy: 0.9939
# Epoch 30/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4767 - wine_quality_loss: 0.4386 - wine_type_loss: 0.0381 - wine_quality_root_mean_squared_error: 0.6621 - wine_type_accuracy: 0.9946 - val_loss: 0.5115 - val_wine_quality_loss: 0.4739 - val_wine_type_loss: 0.0376 - val_wine_quality_root_mean_squared_error: 0.6884 - val_wine_type_accuracy: 0.9939
# Epoch 31/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4659 - wine_quality_loss: 0.4313 - wine_type_loss: 0.0346 - wine_quality_root_mean_squared_error: 0.6565 - wine_type_accuracy: 0.9928 - val_loss: 0.4951 - val_wine_quality_loss: 0.4578 - val_wine_type_loss: 0.0373 - val_wine_quality_root_mean_squared_error: 0.6766 - val_wine_type_accuracy: 0.9939
# Epoch 32/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4598 - wine_quality_loss: 0.4218 - wine_type_loss: 0.0380 - wine_quality_root_mean_squared_error: 0.6491 - wine_type_accuracy: 0.9945 - val_loss: 0.4821 - val_wine_quality_loss: 0.4452 - val_wine_type_loss: 0.0369 - val_wine_quality_root_mean_squared_error: 0.6672 - val_wine_type_accuracy: 0.9939
# Epoch 33/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4368 - wine_quality_loss: 0.3971 - wine_type_loss: 0.0396 - wine_quality_root_mean_squared_error: 0.6300 - wine_type_accuracy: 0.9937 - val_loss: 0.4725 - val_wine_quality_loss: 0.4358 - val_wine_type_loss: 0.0366 - val_wine_quality_root_mean_squared_error: 0.6602 - val_wine_type_accuracy: 0.9949
# Epoch 34/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4454 - wine_quality_loss: 0.4095 - wine_type_loss: 0.0360 - wine_quality_root_mean_squared_error: 0.6398 - wine_type_accuracy: 0.9945 - val_loss: 0.4663 - val_wine_quality_loss: 0.4299 - val_wine_type_loss: 0.0364 - val_wine_quality_root_mean_squared_error: 0.6557 - val_wine_type_accuracy: 0.9949
# Epoch 35/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4329 - wine_quality_loss: 0.4022 - wine_type_loss: 0.0307 - wine_quality_root_mean_squared_error: 0.6341 - wine_type_accuracy: 0.9941 - val_loss: 0.4604 - val_wine_quality_loss: 0.4243 - val_wine_type_loss: 0.0361 - val_wine_quality_root_mean_squared_error: 0.6514 - val_wine_type_accuracy: 0.9949
# Epoch 36/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4227 - wine_quality_loss: 0.3801 - wine_type_loss: 0.0426 - wine_quality_root_mean_squared_error: 0.6165 - wine_type_accuracy: 0.9927 - val_loss: 0.4443 - val_wine_quality_loss: 0.4084 - val_wine_type_loss: 0.0359 - val_wine_quality_root_mean_squared_error: 0.6391 - val_wine_type_accuracy: 0.9949
# Epoch 37/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.4383 - wine_quality_loss: 0.3965 - wine_type_loss: 0.0417 - wine_quality_root_mean_squared_error: 0.6295 - wine_type_accuracy: 0.9931 - val_loss: 0.4392 - val_wine_quality_loss: 0.4036 - val_wine_type_loss: 0.0356 - val_wine_quality_root_mean_squared_error: 0.6353 - val_wine_type_accuracy: 0.9949
# Epoch 38/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3961 - wine_quality_loss: 0.3725 - wine_type_loss: 0.0236 - wine_quality_root_mean_squared_error: 0.6103 - wine_type_accuracy: 0.9960 - val_loss: 0.4347 - val_wine_quality_loss: 0.3993 - val_wine_type_loss: 0.0354 - val_wine_quality_root_mean_squared_error: 0.6319 - val_wine_type_accuracy: 0.9949
# Epoch 39/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.4131 - wine_quality_loss: 0.3853 - wine_type_loss: 0.0278 - wine_quality_root_mean_squared_error: 0.6206 - wine_type_accuracy: 0.9937 - val_loss: 0.4314 - val_wine_quality_loss: 0.3963 - val_wine_type_loss: 0.0351 - val_wine_quality_root_mean_squared_error: 0.6296 - val_wine_type_accuracy: 0.9949
# Epoch 40/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3820 - wine_quality_loss: 0.3497 - wine_type_loss: 0.0323 - wine_quality_root_mean_squared_error: 0.5912 - wine_type_accuracy: 0.9929 - val_loss: 0.4264 - val_wine_quality_loss: 0.3915 - val_wine_type_loss: 0.0349 - val_wine_quality_root_mean_squared_error: 0.6257 - val_wine_type_accuracy: 0.9949
# Epoch 41/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3636 - wine_quality_loss: 0.3396 - wine_type_loss: 0.0240 - wine_quality_root_mean_squared_error: 0.5825 - wine_type_accuracy: 0.9942 - val_loss: 0.4201 - val_wine_quality_loss: 0.3854 - val_wine_type_loss: 0.0347 - val_wine_quality_root_mean_squared_error: 0.6208 - val_wine_type_accuracy: 0.9949
# Epoch 42/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3991 - wine_quality_loss: 0.3681 - wine_type_loss: 0.0310 - wine_quality_root_mean_squared_error: 0.6067 - wine_type_accuracy: 0.9945 - val_loss: 0.4157 - val_wine_quality_loss: 0.3812 - val_wine_type_loss: 0.0345 - val_wine_quality_root_mean_squared_error: 0.6174 - val_wine_type_accuracy: 0.9949
# Epoch 43/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3701 - wine_quality_loss: 0.3426 - wine_type_loss: 0.0276 - wine_quality_root_mean_squared_error: 0.5852 - wine_type_accuracy: 0.9962 - val_loss: 0.4209 - val_wine_quality_loss: 0.3866 - val_wine_type_loss: 0.0343 - val_wine_quality_root_mean_squared_error: 0.6218 - val_wine_type_accuracy: 0.9949
# Epoch 44/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3697 - wine_quality_loss: 0.3494 - wine_type_loss: 0.0203 - wine_quality_root_mean_squared_error: 0.5910 - wine_type_accuracy: 0.9966 - val_loss: 0.4117 - val_wine_quality_loss: 0.3776 - val_wine_type_loss: 0.0341 - val_wine_quality_root_mean_squared_error: 0.6145 - val_wine_type_accuracy: 0.9949
# Epoch 45/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3833 - wine_quality_loss: 0.3381 - wine_type_loss: 0.0452 - wine_quality_root_mean_squared_error: 0.5814 - wine_type_accuracy: 0.9949 - val_loss: 0.4147 - val_wine_quality_loss: 0.3807 - val_wine_type_loss: 0.0340 - val_wine_quality_root_mean_squared_error: 0.6170 - val_wine_type_accuracy: 0.9949
# Epoch 46/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3736 - wine_quality_loss: 0.3334 - wine_type_loss: 0.0403 - wine_quality_root_mean_squared_error: 0.5773 - wine_type_accuracy: 0.9927 - val_loss: 0.4067 - val_wine_quality_loss: 0.3730 - val_wine_type_loss: 0.0338 - val_wine_quality_root_mean_squared_error: 0.6107 - val_wine_type_accuracy: 0.9949
# Epoch 47/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3642 - wine_quality_loss: 0.3315 - wine_type_loss: 0.0327 - wine_quality_root_mean_squared_error: 0.5757 - wine_type_accuracy: 0.9944 - val_loss: 0.4037 - val_wine_quality_loss: 0.3701 - val_wine_type_loss: 0.0336 - val_wine_quality_root_mean_squared_error: 0.6084 - val_wine_type_accuracy: 0.9949
# Epoch 48/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3445 - wine_quality_loss: 0.3200 - wine_type_loss: 0.0245 - wine_quality_root_mean_squared_error: 0.5654 - wine_type_accuracy: 0.9949 - val_loss: 0.4087 - val_wine_quality_loss: 0.3754 - val_wine_type_loss: 0.0334 - val_wine_quality_root_mean_squared_error: 0.6127 - val_wine_type_accuracy: 0.9949
# Epoch 49/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3630 - wine_quality_loss: 0.3289 - wine_type_loss: 0.0342 - wine_quality_root_mean_squared_error: 0.5732 - wine_type_accuracy: 0.9922 - val_loss: 0.3990 - val_wine_quality_loss: 0.3658 - val_wine_type_loss: 0.0332 - val_wine_quality_root_mean_squared_error: 0.6049 - val_wine_type_accuracy: 0.9949
# Epoch 50/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3438 - wine_quality_loss: 0.3255 - wine_type_loss: 0.0184 - wine_quality_root_mean_squared_error: 0.5703 - wine_type_accuracy: 0.9969 - val_loss: 0.3993 - val_wine_quality_loss: 0.3663 - val_wine_type_loss: 0.0331 - val_wine_quality_root_mean_squared_error: 0.6052 - val_wine_type_accuracy: 0.9959
# Epoch 51/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3652 - wine_quality_loss: 0.3322 - wine_type_loss: 0.0330 - wine_quality_root_mean_squared_error: 0.5763 - wine_type_accuracy: 0.9933 - val_loss: 0.3997 - val_wine_quality_loss: 0.3668 - val_wine_type_loss: 0.0329 - val_wine_quality_root_mean_squared_error: 0.6057 - val_wine_type_accuracy: 0.9959
# Epoch 52/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3523 - wine_quality_loss: 0.3253 - wine_type_loss: 0.0269 - wine_quality_root_mean_squared_error: 0.5703 - wine_type_accuracy: 0.9947 - val_loss: 0.3935 - val_wine_quality_loss: 0.3608 - val_wine_type_loss: 0.0328 - val_wine_quality_root_mean_squared_error: 0.6006 - val_wine_type_accuracy: 0.9959
# Epoch 53/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3540 - wine_quality_loss: 0.3292 - wine_type_loss: 0.0249 - wine_quality_root_mean_squared_error: 0.5736 - wine_type_accuracy: 0.9957 - val_loss: 0.3982 - val_wine_quality_loss: 0.3656 - val_wine_type_loss: 0.0326 - val_wine_quality_root_mean_squared_error: 0.6046 - val_wine_type_accuracy: 0.9959
# Epoch 54/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3639 - wine_quality_loss: 0.3343 - wine_type_loss: 0.0296 - wine_quality_root_mean_squared_error: 0.5779 - wine_type_accuracy: 0.9955 - val_loss: 0.3923 - val_wine_quality_loss: 0.3598 - val_wine_type_loss: 0.0325 - val_wine_quality_root_mean_squared_error: 0.5998 - val_wine_type_accuracy: 0.9959
# Epoch 55/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3581 - wine_quality_loss: 0.3176 - wine_type_loss: 0.0405 - wine_quality_root_mean_squared_error: 0.5634 - wine_type_accuracy: 0.9925 - val_loss: 0.3864 - val_wine_quality_loss: 0.3541 - val_wine_type_loss: 0.0323 - val_wine_quality_root_mean_squared_error: 0.5951 - val_wine_type_accuracy: 0.9959
# Epoch 56/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3527 - wine_quality_loss: 0.3240 - wine_type_loss: 0.0287 - wine_quality_root_mean_squared_error: 0.5691 - wine_type_accuracy: 0.9938 - val_loss: 0.3886 - val_wine_quality_loss: 0.3564 - val_wine_type_loss: 0.0322 - val_wine_quality_root_mean_squared_error: 0.5970 - val_wine_type_accuracy: 0.9959
# Epoch 57/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3472 - wine_quality_loss: 0.3232 - wine_type_loss: 0.0240 - wine_quality_root_mean_squared_error: 0.5684 - wine_type_accuracy: 0.9949 - val_loss: 0.3905 - val_wine_quality_loss: 0.3584 - val_wine_type_loss: 0.0321 - val_wine_quality_root_mean_squared_error: 0.5987 - val_wine_type_accuracy: 0.9949
# Epoch 58/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3296 - wine_quality_loss: 0.3092 - wine_type_loss: 0.0204 - wine_quality_root_mean_squared_error: 0.5559 - wine_type_accuracy: 0.9961 - val_loss: 0.3845 - val_wine_quality_loss: 0.3526 - val_wine_type_loss: 0.0319 - val_wine_quality_root_mean_squared_error: 0.5938 - val_wine_type_accuracy: 0.9959
# Epoch 59/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.3331 - wine_quality_loss: 0.2999 - wine_type_loss: 0.0332 - wine_quality_root_mean_squared_error: 0.5475 - wine_type_accuracy: 0.9926 - val_loss: 0.3890 - val_wine_quality_loss: 0.3573 - val_wine_type_loss: 0.0318 - val_wine_quality_root_mean_squared_error: 0.5977 - val_wine_type_accuracy: 0.9970
# Epoch 60/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3340 - wine_quality_loss: 0.3093 - wine_type_loss: 0.0247 - wine_quality_root_mean_squared_error: 0.5558 - wine_type_accuracy: 0.9955 - val_loss: 0.3842 - val_wine_quality_loss: 0.3526 - val_wine_type_loss: 0.0316 - val_wine_quality_root_mean_squared_error: 0.5938 - val_wine_type_accuracy: 0.9970
# Epoch 61/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3494 - wine_quality_loss: 0.3215 - wine_type_loss: 0.0279 - wine_quality_root_mean_squared_error: 0.5669 - wine_type_accuracy: 0.9940 - val_loss: 0.3818 - val_wine_quality_loss: 0.3504 - val_wine_type_loss: 0.0315 - val_wine_quality_root_mean_squared_error: 0.5919 - val_wine_type_accuracy: 0.9970
# Epoch 62/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3254 - wine_quality_loss: 0.3023 - wine_type_loss: 0.0231 - wine_quality_root_mean_squared_error: 0.5496 - wine_type_accuracy: 0.9948 - val_loss: 0.3821 - val_wine_quality_loss: 0.3508 - val_wine_type_loss: 0.0313 - val_wine_quality_root_mean_squared_error: 0.5923 - val_wine_type_accuracy: 0.9959
# Epoch 63/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3417 - wine_quality_loss: 0.3049 - wine_type_loss: 0.0368 - wine_quality_root_mean_squared_error: 0.5519 - wine_type_accuracy: 0.9953 - val_loss: 0.3860 - val_wine_quality_loss: 0.3548 - val_wine_type_loss: 0.0312 - val_wine_quality_root_mean_squared_error: 0.5956 - val_wine_type_accuracy: 0.9970
# Epoch 64/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3311 - wine_quality_loss: 0.3002 - wine_type_loss: 0.0309 - wine_quality_root_mean_squared_error: 0.5476 - wine_type_accuracy: 0.9952 - val_loss: 0.3829 - val_wine_quality_loss: 0.3518 - val_wine_type_loss: 0.0311 - val_wine_quality_root_mean_squared_error: 0.5931 - val_wine_type_accuracy: 0.9970
# Epoch 65/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3323 - wine_quality_loss: 0.3129 - wine_type_loss: 0.0194 - wine_quality_root_mean_squared_error: 0.5593 - wine_type_accuracy: 0.9951 - val_loss: 0.3820 - val_wine_quality_loss: 0.3510 - val_wine_type_loss: 0.0310 - val_wine_quality_root_mean_squared_error: 0.5924 - val_wine_type_accuracy: 0.9970
# Epoch 66/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3445 - wine_quality_loss: 0.3150 - wine_type_loss: 0.0295 - wine_quality_root_mean_squared_error: 0.5610 - wine_type_accuracy: 0.9938 - val_loss: 0.3771 - val_wine_quality_loss: 0.3463 - val_wine_type_loss: 0.0308 - val_wine_quality_root_mean_squared_error: 0.5885 - val_wine_type_accuracy: 0.9970
# Epoch 67/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3380 - wine_quality_loss: 0.3092 - wine_type_loss: 0.0288 - wine_quality_root_mean_squared_error: 0.5559 - wine_type_accuracy: 0.9938 - val_loss: 0.3819 - val_wine_quality_loss: 0.3512 - val_wine_type_loss: 0.0307 - val_wine_quality_root_mean_squared_error: 0.5926 - val_wine_type_accuracy: 0.9970
# Epoch 68/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3304 - wine_quality_loss: 0.3080 - wine_type_loss: 0.0225 - wine_quality_root_mean_squared_error: 0.5548 - wine_type_accuracy: 0.9949 - val_loss: 0.3863 - val_wine_quality_loss: 0.3557 - val_wine_type_loss: 0.0306 - val_wine_quality_root_mean_squared_error: 0.5964 - val_wine_type_accuracy: 0.9970
# Epoch 69/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3155 - wine_quality_loss: 0.2927 - wine_type_loss: 0.0228 - wine_quality_root_mean_squared_error: 0.5407 - wine_type_accuracy: 0.9963 - val_loss: 0.3804 - val_wine_quality_loss: 0.3499 - val_wine_type_loss: 0.0304 - val_wine_quality_root_mean_squared_error: 0.5916 - val_wine_type_accuracy: 0.9959
# Epoch 70/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3227 - wine_quality_loss: 0.3030 - wine_type_loss: 0.0198 - wine_quality_root_mean_squared_error: 0.5501 - wine_type_accuracy: 0.9968 - val_loss: 0.3792 - val_wine_quality_loss: 0.3489 - val_wine_type_loss: 0.0304 - val_wine_quality_root_mean_squared_error: 0.5907 - val_wine_type_accuracy: 0.9970
# Epoch 71/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3277 - wine_quality_loss: 0.2982 - wine_type_loss: 0.0294 - wine_quality_root_mean_squared_error: 0.5460 - wine_type_accuracy: 0.9947 - val_loss: 0.3785 - val_wine_quality_loss: 0.3482 - val_wine_type_loss: 0.0302 - val_wine_quality_root_mean_squared_error: 0.5901 - val_wine_type_accuracy: 0.9970
# Epoch 72/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3386 - wine_quality_loss: 0.3188 - wine_type_loss: 0.0197 - wine_quality_root_mean_squared_error: 0.5644 - wine_type_accuracy: 0.9958 - val_loss: 0.3797 - val_wine_quality_loss: 0.3496 - val_wine_type_loss: 0.0301 - val_wine_quality_root_mean_squared_error: 0.5913 - val_wine_type_accuracy: 0.9970
# Epoch 73/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3193 - wine_quality_loss: 0.2956 - wine_type_loss: 0.0236 - wine_quality_root_mean_squared_error: 0.5435 - wine_type_accuracy: 0.9956 - val_loss: 0.3795 - val_wine_quality_loss: 0.3494 - val_wine_type_loss: 0.0300 - val_wine_quality_root_mean_squared_error: 0.5911 - val_wine_type_accuracy: 0.9970
# Epoch 74/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3361 - wine_quality_loss: 0.3064 - wine_type_loss: 0.0296 - wine_quality_root_mean_squared_error: 0.5535 - wine_type_accuracy: 0.9953 - val_loss: 0.3807 - val_wine_quality_loss: 0.3508 - val_wine_type_loss: 0.0299 - val_wine_quality_root_mean_squared_error: 0.5923 - val_wine_type_accuracy: 0.9970
# Epoch 75/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3376 - wine_quality_loss: 0.3083 - wine_type_loss: 0.0294 - wine_quality_root_mean_squared_error: 0.5551 - wine_type_accuracy: 0.9950 - val_loss: 0.3817 - val_wine_quality_loss: 0.3519 - val_wine_type_loss: 0.0298 - val_wine_quality_root_mean_squared_error: 0.5932 - val_wine_type_accuracy: 0.9970
# Epoch 76/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3123 - wine_quality_loss: 0.2889 - wine_type_loss: 0.0234 - wine_quality_root_mean_squared_error: 0.5372 - wine_type_accuracy: 0.9954 - val_loss: 0.3787 - val_wine_quality_loss: 0.3490 - val_wine_type_loss: 0.0297 - val_wine_quality_root_mean_squared_error: 0.5908 - val_wine_type_accuracy: 0.9970
# Epoch 77/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3095 - wine_quality_loss: 0.2926 - wine_type_loss: 0.0169 - wine_quality_root_mean_squared_error: 0.5409 - wine_type_accuracy: 0.9957 - val_loss: 0.3766 - val_wine_quality_loss: 0.3470 - val_wine_type_loss: 0.0296 - val_wine_quality_root_mean_squared_error: 0.5891 - val_wine_type_accuracy: 0.9970
# Epoch 78/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3317 - wine_quality_loss: 0.3059 - wine_type_loss: 0.0257 - wine_quality_root_mean_squared_error: 0.5529 - wine_type_accuracy: 0.9950 - val_loss: 0.3801 - val_wine_quality_loss: 0.3507 - val_wine_type_loss: 0.0294 - val_wine_quality_root_mean_squared_error: 0.5922 - val_wine_type_accuracy: 0.9970
# Epoch 79/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3210 - wine_quality_loss: 0.3013 - wine_type_loss: 0.0197 - wine_quality_root_mean_squared_error: 0.5488 - wine_type_accuracy: 0.9959 - val_loss: 0.3754 - val_wine_quality_loss: 0.3461 - val_wine_type_loss: 0.0293 - val_wine_quality_root_mean_squared_error: 0.5883 - val_wine_type_accuracy: 0.9970
# Epoch 80/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3156 - wine_quality_loss: 0.2922 - wine_type_loss: 0.0234 - wine_quality_root_mean_squared_error: 0.5403 - wine_type_accuracy: 0.9964 - val_loss: 0.3780 - val_wine_quality_loss: 0.3487 - val_wine_type_loss: 0.0292 - val_wine_quality_root_mean_squared_error: 0.5905 - val_wine_type_accuracy: 0.9970
# Epoch 81/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3158 - wine_quality_loss: 0.2906 - wine_type_loss: 0.0252 - wine_quality_root_mean_squared_error: 0.5390 - wine_type_accuracy: 0.9949 - val_loss: 0.3775 - val_wine_quality_loss: 0.3484 - val_wine_type_loss: 0.0291 - val_wine_quality_root_mean_squared_error: 0.5903 - val_wine_type_accuracy: 0.9970
# Epoch 82/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3175 - wine_quality_loss: 0.3040 - wine_type_loss: 0.0135 - wine_quality_root_mean_squared_error: 0.5512 - wine_type_accuracy: 0.9983 - val_loss: 0.3835 - val_wine_quality_loss: 0.3545 - val_wine_type_loss: 0.0291 - val_wine_quality_root_mean_squared_error: 0.5954 - val_wine_type_accuracy: 0.9970
# Epoch 83/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3092 - wine_quality_loss: 0.2902 - wine_type_loss: 0.0190 - wine_quality_root_mean_squared_error: 0.5386 - wine_type_accuracy: 0.9965 - val_loss: 0.3722 - val_wine_quality_loss: 0.3432 - val_wine_type_loss: 0.0290 - val_wine_quality_root_mean_squared_error: 0.5858 - val_wine_type_accuracy: 0.9970
# Epoch 84/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3216 - wine_quality_loss: 0.2987 - wine_type_loss: 0.0229 - wine_quality_root_mean_squared_error: 0.5465 - wine_type_accuracy: 0.9960 - val_loss: 0.3769 - val_wine_quality_loss: 0.3481 - val_wine_type_loss: 0.0288 - val_wine_quality_root_mean_squared_error: 0.5900 - val_wine_type_accuracy: 0.9970
# Epoch 85/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3045 - wine_quality_loss: 0.2874 - wine_type_loss: 0.0171 - wine_quality_root_mean_squared_error: 0.5360 - wine_type_accuracy: 0.9974 - val_loss: 0.3742 - val_wine_quality_loss: 0.3455 - val_wine_type_loss: 0.0288 - val_wine_quality_root_mean_squared_error: 0.5878 - val_wine_type_accuracy: 0.9970
# Epoch 86/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3033 - wine_quality_loss: 0.2806 - wine_type_loss: 0.0227 - wine_quality_root_mean_squared_error: 0.5296 - wine_type_accuracy: 0.9953 - val_loss: 0.3761 - val_wine_quality_loss: 0.3475 - val_wine_type_loss: 0.0286 - val_wine_quality_root_mean_squared_error: 0.5895 - val_wine_type_accuracy: 0.9970
# Epoch 87/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3206 - wine_quality_loss: 0.2943 - wine_type_loss: 0.0263 - wine_quality_root_mean_squared_error: 0.5424 - wine_type_accuracy: 0.9938 - val_loss: 0.3737 - val_wine_quality_loss: 0.3452 - val_wine_type_loss: 0.0285 - val_wine_quality_root_mean_squared_error: 0.5875 - val_wine_type_accuracy: 0.9970
# Epoch 88/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3288 - wine_quality_loss: 0.2948 - wine_type_loss: 0.0341 - wine_quality_root_mean_squared_error: 0.5429 - wine_type_accuracy: 0.9939 - val_loss: 0.3771 - val_wine_quality_loss: 0.3487 - val_wine_type_loss: 0.0284 - val_wine_quality_root_mean_squared_error: 0.5905 - val_wine_type_accuracy: 0.9970
# Epoch 89/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3158 - wine_quality_loss: 0.2941 - wine_type_loss: 0.0217 - wine_quality_root_mean_squared_error: 0.5422 - wine_type_accuracy: 0.9961 - val_loss: 0.3839 - val_wine_quality_loss: 0.3556 - val_wine_type_loss: 0.0283 - val_wine_quality_root_mean_squared_error: 0.5964 - val_wine_type_accuracy: 0.9970
# Epoch 90/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3237 - wine_quality_loss: 0.2907 - wine_type_loss: 0.0330 - wine_quality_root_mean_squared_error: 0.5392 - wine_type_accuracy: 0.9945 - val_loss: 0.3751 - val_wine_quality_loss: 0.3468 - val_wine_type_loss: 0.0283 - val_wine_quality_root_mean_squared_error: 0.5889 - val_wine_type_accuracy: 0.9970
# Epoch 91/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3132 - wine_quality_loss: 0.2888 - wine_type_loss: 0.0244 - wine_quality_root_mean_squared_error: 0.5374 - wine_type_accuracy: 0.9965 - val_loss: 0.3761 - val_wine_quality_loss: 0.3480 - val_wine_type_loss: 0.0282 - val_wine_quality_root_mean_squared_error: 0.5899 - val_wine_type_accuracy: 0.9970
# Epoch 92/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3152 - wine_quality_loss: 0.2930 - wine_type_loss: 0.0222 - wine_quality_root_mean_squared_error: 0.5412 - wine_type_accuracy: 0.9956 - val_loss: 0.3786 - val_wine_quality_loss: 0.3505 - val_wine_type_loss: 0.0281 - val_wine_quality_root_mean_squared_error: 0.5920 - val_wine_type_accuracy: 0.9970
# Epoch 93/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3094 - wine_quality_loss: 0.2950 - wine_type_loss: 0.0144 - wine_quality_root_mean_squared_error: 0.5431 - wine_type_accuracy: 0.9972 - val_loss: 0.3752 - val_wine_quality_loss: 0.3472 - val_wine_type_loss: 0.0280 - val_wine_quality_root_mean_squared_error: 0.5892 - val_wine_type_accuracy: 0.9970
# Epoch 94/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3039 - wine_quality_loss: 0.2784 - wine_type_loss: 0.0255 - wine_quality_root_mean_squared_error: 0.5275 - wine_type_accuracy: 0.9965 - val_loss: 0.3766 - val_wine_quality_loss: 0.3487 - val_wine_type_loss: 0.0279 - val_wine_quality_root_mean_squared_error: 0.5905 - val_wine_type_accuracy: 0.9970
# Epoch 95/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3046 - wine_quality_loss: 0.2834 - wine_type_loss: 0.0212 - wine_quality_root_mean_squared_error: 0.5323 - wine_type_accuracy: 0.9957 - val_loss: 0.3694 - val_wine_quality_loss: 0.3415 - val_wine_type_loss: 0.0279 - val_wine_quality_root_mean_squared_error: 0.5844 - val_wine_type_accuracy: 0.9970
# Epoch 96/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3146 - wine_quality_loss: 0.2918 - wine_type_loss: 0.0228 - wine_quality_root_mean_squared_error: 0.5399 - wine_type_accuracy: 0.9969 - val_loss: 0.3780 - val_wine_quality_loss: 0.3503 - val_wine_type_loss: 0.0277 - val_wine_quality_root_mean_squared_error: 0.5919 - val_wine_type_accuracy: 0.9970
# Epoch 97/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3363 - wine_quality_loss: 0.3033 - wine_type_loss: 0.0330 - wine_quality_root_mean_squared_error: 0.5504 - wine_type_accuracy: 0.9933 - val_loss: 0.3715 - val_wine_quality_loss: 0.3438 - val_wine_type_loss: 0.0277 - val_wine_quality_root_mean_squared_error: 0.5863 - val_wine_type_accuracy: 0.9970
# Epoch 98/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3087 - wine_quality_loss: 0.2818 - wine_type_loss: 0.0269 - wine_quality_root_mean_squared_error: 0.5308 - wine_type_accuracy: 0.9958 - val_loss: 0.3703 - val_wine_quality_loss: 0.3427 - val_wine_type_loss: 0.0275 - val_wine_quality_root_mean_squared_error: 0.5854 - val_wine_type_accuracy: 0.9970
# Epoch 99/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2984 - wine_quality_loss: 0.2831 - wine_type_loss: 0.0153 - wine_quality_root_mean_squared_error: 0.5319 - wine_type_accuracy: 0.9975 - val_loss: 0.3773 - val_wine_quality_loss: 0.3499 - val_wine_type_loss: 0.0275 - val_wine_quality_root_mean_squared_error: 0.5915 - val_wine_type_accuracy: 0.9970
# Epoch 100/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3026 - wine_quality_loss: 0.2789 - wine_type_loss: 0.0237 - wine_quality_root_mean_squared_error: 0.5280 - wine_type_accuracy: 0.9958 - val_loss: 0.3691 - val_wine_quality_loss: 0.3417 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5846 - val_wine_type_accuracy: 0.9970
# Epoch 101/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3208 - wine_quality_loss: 0.2951 - wine_type_loss: 0.0257 - wine_quality_root_mean_squared_error: 0.5431 - wine_type_accuracy: 0.9951 - val_loss: 0.3759 - val_wine_quality_loss: 0.3485 - val_wine_type_loss: 0.0274 - val_wine_quality_root_mean_squared_error: 0.5904 - val_wine_type_accuracy: 0.9970
# Epoch 102/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3007 - wine_quality_loss: 0.2868 - wine_type_loss: 0.0140 - wine_quality_root_mean_squared_error: 0.5355 - wine_type_accuracy: 0.9986 - val_loss: 0.3740 - val_wine_quality_loss: 0.3467 - val_wine_type_loss: 0.0273 - val_wine_quality_root_mean_squared_error: 0.5888 - val_wine_type_accuracy: 0.9970
# Epoch 103/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3077 - wine_quality_loss: 0.2880 - wine_type_loss: 0.0197 - wine_quality_root_mean_squared_error: 0.5366 - wine_type_accuracy: 0.9969 - val_loss: 0.3699 - val_wine_quality_loss: 0.3428 - val_wine_type_loss: 0.0272 - val_wine_quality_root_mean_squared_error: 0.5855 - val_wine_type_accuracy: 0.9970
# Epoch 104/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3051 - wine_quality_loss: 0.2872 - wine_type_loss: 0.0179 - wine_quality_root_mean_squared_error: 0.5358 - wine_type_accuracy: 0.9964 - val_loss: 0.3681 - val_wine_quality_loss: 0.3411 - val_wine_type_loss: 0.0271 - val_wine_quality_root_mean_squared_error: 0.5840 - val_wine_type_accuracy: 0.9970
# Epoch 105/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3103 - wine_quality_loss: 0.2931 - wine_type_loss: 0.0172 - wine_quality_root_mean_squared_error: 0.5413 - wine_type_accuracy: 0.9971 - val_loss: 0.3715 - val_wine_quality_loss: 0.3444 - val_wine_type_loss: 0.0271 - val_wine_quality_root_mean_squared_error: 0.5869 - val_wine_type_accuracy: 0.9970
# Epoch 106/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3149 - wine_quality_loss: 0.2919 - wine_type_loss: 0.0230 - wine_quality_root_mean_squared_error: 0.5402 - wine_type_accuracy: 0.9959 - val_loss: 0.3682 - val_wine_quality_loss: 0.3412 - val_wine_type_loss: 0.0270 - val_wine_quality_root_mean_squared_error: 0.5841 - val_wine_type_accuracy: 0.9970
# Epoch 107/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3046 - wine_quality_loss: 0.2827 - wine_type_loss: 0.0218 - wine_quality_root_mean_squared_error: 0.5317 - wine_type_accuracy: 0.9961 - val_loss: 0.3673 - val_wine_quality_loss: 0.3403 - val_wine_type_loss: 0.0269 - val_wine_quality_root_mean_squared_error: 0.5834 - val_wine_type_accuracy: 0.9970
# Epoch 108/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3096 - wine_quality_loss: 0.2858 - wine_type_loss: 0.0238 - wine_quality_root_mean_squared_error: 0.5345 - wine_type_accuracy: 0.9964 - val_loss: 0.3697 - val_wine_quality_loss: 0.3429 - val_wine_type_loss: 0.0268 - val_wine_quality_root_mean_squared_error: 0.5856 - val_wine_type_accuracy: 0.9970
# Epoch 109/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3023 - wine_quality_loss: 0.2802 - wine_type_loss: 0.0221 - wine_quality_root_mean_squared_error: 0.5294 - wine_type_accuracy: 0.9959 - val_loss: 0.3656 - val_wine_quality_loss: 0.3389 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5821 - val_wine_type_accuracy: 0.9970
# Epoch 110/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2955 - wine_quality_loss: 0.2691 - wine_type_loss: 0.0265 - wine_quality_root_mean_squared_error: 0.5187 - wine_type_accuracy: 0.9963 - val_loss: 0.3706 - val_wine_quality_loss: 0.3440 - val_wine_type_loss: 0.0267 - val_wine_quality_root_mean_squared_error: 0.5865 - val_wine_type_accuracy: 0.9970
# Epoch 111/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3152 - wine_quality_loss: 0.2864 - wine_type_loss: 0.0288 - wine_quality_root_mean_squared_error: 0.5351 - wine_type_accuracy: 0.9954 - val_loss: 0.3689 - val_wine_quality_loss: 0.3423 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5851 - val_wine_type_accuracy: 0.9970
# Epoch 112/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2985 - wine_quality_loss: 0.2788 - wine_type_loss: 0.0197 - wine_quality_root_mean_squared_error: 0.5279 - wine_type_accuracy: 0.9956 - val_loss: 0.3676 - val_wine_quality_loss: 0.3410 - val_wine_type_loss: 0.0266 - val_wine_quality_root_mean_squared_error: 0.5840 - val_wine_type_accuracy: 0.9970
# Epoch 113/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2964 - wine_quality_loss: 0.2763 - wine_type_loss: 0.0201 - wine_quality_root_mean_squared_error: 0.5256 - wine_type_accuracy: 0.9965 - val_loss: 0.3691 - val_wine_quality_loss: 0.3426 - val_wine_type_loss: 0.0264 - val_wine_quality_root_mean_squared_error: 0.5853 - val_wine_type_accuracy: 0.9970
# Epoch 114/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2823 - wine_quality_loss: 0.2683 - wine_type_loss: 0.0140 - wine_quality_root_mean_squared_error: 0.5179 - wine_type_accuracy: 0.9982 - val_loss: 0.3726 - val_wine_quality_loss: 0.3462 - val_wine_type_loss: 0.0264 - val_wine_quality_root_mean_squared_error: 0.5884 - val_wine_type_accuracy: 0.9970
# Epoch 115/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2988 - wine_quality_loss: 0.2775 - wine_type_loss: 0.0213 - wine_quality_root_mean_squared_error: 0.5267 - wine_type_accuracy: 0.9955 - val_loss: 0.3696 - val_wine_quality_loss: 0.3433 - val_wine_type_loss: 0.0263 - val_wine_quality_root_mean_squared_error: 0.5859 - val_wine_type_accuracy: 0.9970
# Epoch 116/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2806 - wine_quality_loss: 0.2680 - wine_type_loss: 0.0126 - wine_quality_root_mean_squared_error: 0.5176 - wine_type_accuracy: 0.9975 - val_loss: 0.3709 - val_wine_quality_loss: 0.3447 - val_wine_type_loss: 0.0262 - val_wine_quality_root_mean_squared_error: 0.5871 - val_wine_type_accuracy: 0.9970
# Epoch 117/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2932 - wine_quality_loss: 0.2717 - wine_type_loss: 0.0215 - wine_quality_root_mean_squared_error: 0.5212 - wine_type_accuracy: 0.9975 - val_loss: 0.3783 - val_wine_quality_loss: 0.3521 - val_wine_type_loss: 0.0262 - val_wine_quality_root_mean_squared_error: 0.5934 - val_wine_type_accuracy: 0.9970
# Epoch 118/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3080 - wine_quality_loss: 0.2838 - wine_type_loss: 0.0242 - wine_quality_root_mean_squared_error: 0.5327 - wine_type_accuracy: 0.9958 - val_loss: 0.3750 - val_wine_quality_loss: 0.3489 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5907 - val_wine_type_accuracy: 0.9970
# Epoch 119/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3012 - wine_quality_loss: 0.2796 - wine_type_loss: 0.0216 - wine_quality_root_mean_squared_error: 0.5287 - wine_type_accuracy: 0.9954 - val_loss: 0.3716 - val_wine_quality_loss: 0.3455 - val_wine_type_loss: 0.0261 - val_wine_quality_root_mean_squared_error: 0.5878 - val_wine_type_accuracy: 0.9970
# Epoch 120/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3055 - wine_quality_loss: 0.2741 - wine_type_loss: 0.0314 - wine_quality_root_mean_squared_error: 0.5235 - wine_type_accuracy: 0.9954 - val_loss: 0.3704 - val_wine_quality_loss: 0.3444 - val_wine_type_loss: 0.0260 - val_wine_quality_root_mean_squared_error: 0.5869 - val_wine_type_accuracy: 0.9970
# Epoch 121/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3039 - wine_quality_loss: 0.2806 - wine_type_loss: 0.0232 - wine_quality_root_mean_squared_error: 0.5297 - wine_type_accuracy: 0.9953 - val_loss: 0.3656 - val_wine_quality_loss: 0.3396 - val_wine_type_loss: 0.0259 - val_wine_quality_root_mean_squared_error: 0.5828 - val_wine_type_accuracy: 0.9970
# Epoch 122/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2918 - wine_quality_loss: 0.2752 - wine_type_loss: 0.0167 - wine_quality_root_mean_squared_error: 0.5245 - wine_type_accuracy: 0.9965 - val_loss: 0.3720 - val_wine_quality_loss: 0.3461 - val_wine_type_loss: 0.0259 - val_wine_quality_root_mean_squared_error: 0.5883 - val_wine_type_accuracy: 0.9970
# Epoch 123/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3052 - wine_quality_loss: 0.2782 - wine_type_loss: 0.0270 - wine_quality_root_mean_squared_error: 0.5274 - wine_type_accuracy: 0.9961 - val_loss: 0.3788 - val_wine_quality_loss: 0.3530 - val_wine_type_loss: 0.0258 - val_wine_quality_root_mean_squared_error: 0.5941 - val_wine_type_accuracy: 0.9970
# Epoch 124/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.3027 - wine_quality_loss: 0.2740 - wine_type_loss: 0.0287 - wine_quality_root_mean_squared_error: 0.5233 - wine_type_accuracy: 0.9943 - val_loss: 0.3710 - val_wine_quality_loss: 0.3452 - val_wine_type_loss: 0.0258 - val_wine_quality_root_mean_squared_error: 0.5875 - val_wine_type_accuracy: 0.9970
# Epoch 125/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2968 - wine_quality_loss: 0.2779 - wine_type_loss: 0.0189 - wine_quality_root_mean_squared_error: 0.5271 - wine_type_accuracy: 0.9971 - val_loss: 0.3676 - val_wine_quality_loss: 0.3419 - val_wine_type_loss: 0.0257 - val_wine_quality_root_mean_squared_error: 0.5847 - val_wine_type_accuracy: 0.9970
# Epoch 126/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2902 - wine_quality_loss: 0.2689 - wine_type_loss: 0.0214 - wine_quality_root_mean_squared_error: 0.5184 - wine_type_accuracy: 0.9954 - val_loss: 0.3703 - val_wine_quality_loss: 0.3447 - val_wine_type_loss: 0.0256 - val_wine_quality_root_mean_squared_error: 0.5871 - val_wine_type_accuracy: 0.9970
# Epoch 127/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.3168 - wine_quality_loss: 0.2921 - wine_type_loss: 0.0247 - wine_quality_root_mean_squared_error: 0.5402 - wine_type_accuracy: 0.9959 - val_loss: 0.3669 - val_wine_quality_loss: 0.3413 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5842 - val_wine_type_accuracy: 0.9970
# Epoch 128/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2935 - wine_quality_loss: 0.2759 - wine_type_loss: 0.0176 - wine_quality_root_mean_squared_error: 0.5252 - wine_type_accuracy: 0.9967 - val_loss: 0.3700 - val_wine_quality_loss: 0.3445 - val_wine_type_loss: 0.0255 - val_wine_quality_root_mean_squared_error: 0.5870 - val_wine_type_accuracy: 0.9970
# Epoch 129/180
# ...
# Epoch 139/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2819 - wine_quality_loss: 0.2629 - wine_type_loss: 0.0190 - wine_quality_root_mean_squared_error: 0.5125 - wine_type_accuracy: 0.9964 - val_loss: 0.3682 - val_wine_quality_loss: 0.3433 - val_wine_type_loss: 0.0249 - val_wine_quality_root_mean_squared_error: 0.5859 - val_wine_type_accuracy: 0.9970
# Epoch 140/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2790 - wine_quality_loss: 0.2600 - wine_type_loss: 0.0190 - wine_quality_root_mean_squared_error: 0.5093 - wine_type_accuracy: 0.9966 - val_loss: 0.3646 - val_wine_quality_loss: 0.3397 - val_wine_type_loss: 0.0248 - val_wine_quality_root_mean_squared_error: 0.5829 - val_wine_type_accuracy: 0.9970
# Epoch 141/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2716 - wine_quality_loss: 0.2573 - wine_type_loss: 0.0143 - wine_quality_root_mean_squared_error: 0.5069 - wine_type_accuracy: 0.9980 - val_loss: 0.3648 - val_wine_quality_loss: 0.3401 - val_wine_type_loss: 0.0248 - val_wine_quality_root_mean_squared_error: 0.5832 - val_wine_type_accuracy: 0.9970
# Epoch 142/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2844 - wine_quality_loss: 0.2684 - wine_type_loss: 0.0160 - wine_quality_root_mean_squared_error: 0.5180 - wine_type_accuracy: 0.9973 - val_loss: 0.3659 - val_wine_quality_loss: 0.3412 - val_wine_type_loss: 0.0247 - val_wine_quality_root_mean_squared_error: 0.5841 - val_wine_type_accuracy: 0.9970
# Epoch 143/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2718 - wine_quality_loss: 0.2523 - wine_type_loss: 0.0195 - wine_quality_root_mean_squared_error: 0.5021 - wine_type_accuracy: 0.9969 - val_loss: 0.3682 - val_wine_quality_loss: 0.3436 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5862 - val_wine_type_accuracy: 0.9970
# Epoch 144/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2837 - wine_quality_loss: 0.2597 - wine_type_loss: 0.0241 - wine_quality_root_mean_squared_error: 0.5094 - wine_type_accuracy: 0.9952 - val_loss: 0.3678 - val_wine_quality_loss: 0.3432 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5858 - val_wine_type_accuracy: 0.9970
# Epoch 145/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2861 - wine_quality_loss: 0.2640 - wine_type_loss: 0.0222 - wine_quality_root_mean_squared_error: 0.5137 - wine_type_accuracy: 0.9965 - val_loss: 0.3638 - val_wine_quality_loss: 0.3392 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5824 - val_wine_type_accuracy: 0.9970
# Epoch 146/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2820 - wine_quality_loss: 0.2669 - wine_type_loss: 0.0151 - wine_quality_root_mean_squared_error: 0.5166 - wine_type_accuracy: 0.9974 - val_loss: 0.3668 - val_wine_quality_loss: 0.3422 - val_wine_type_loss: 0.0246 - val_wine_quality_root_mean_squared_error: 0.5850 - val_wine_type_accuracy: 0.9970
# Epoch 147/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2892 - wine_quality_loss: 0.2712 - wine_type_loss: 0.0179 - wine_quality_root_mean_squared_error: 0.5207 - wine_type_accuracy: 0.9964 - val_loss: 0.3741 - val_wine_quality_loss: 0.3496 - val_wine_type_loss: 0.0245 - val_wine_quality_root_mean_squared_error: 0.5913 - val_wine_type_accuracy: 0.9970
# Epoch 148/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2872 - wine_quality_loss: 0.2668 - wine_type_loss: 0.0204 - wine_quality_root_mean_squared_error: 0.5165 - wine_type_accuracy: 0.9972 - val_loss: 0.3653 - val_wine_quality_loss: 0.3409 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5839 - val_wine_type_accuracy: 0.9970
# Epoch 149/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2884 - wine_quality_loss: 0.2600 - wine_type_loss: 0.0284 - wine_quality_root_mean_squared_error: 0.5099 - wine_type_accuracy: 0.9966 - val_loss: 0.3674 - val_wine_quality_loss: 0.3431 - val_wine_type_loss: 0.0244 - val_wine_quality_root_mean_squared_error: 0.5857 - val_wine_type_accuracy: 0.9970
# Epoch 150/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2748 - wine_quality_loss: 0.2615 - wine_type_loss: 0.0133 - wine_quality_root_mean_squared_error: 0.5113 - wine_type_accuracy: 0.9971 - val_loss: 0.3775 - val_wine_quality_loss: 0.3532 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5943 - val_wine_type_accuracy: 0.9970
# Epoch 151/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2887 - wine_quality_loss: 0.2659 - wine_type_loss: 0.0228 - wine_quality_root_mean_squared_error: 0.5154 - wine_type_accuracy: 0.9971 - val_loss: 0.3673 - val_wine_quality_loss: 0.3430 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5857 - val_wine_type_accuracy: 0.9970
# Epoch 152/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2894 - wine_quality_loss: 0.2738 - wine_type_loss: 0.0156 - wine_quality_root_mean_squared_error: 0.5233 - wine_type_accuracy: 0.9969 - val_loss: 0.3709 - val_wine_quality_loss: 0.3467 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5888 - val_wine_type_accuracy: 0.9970
# Epoch 153/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2813 - wine_quality_loss: 0.2694 - wine_type_loss: 0.0119 - wine_quality_root_mean_squared_error: 0.5189 - wine_type_accuracy: 0.9978 - val_loss: 0.3675 - val_wine_quality_loss: 0.3433 - val_wine_type_loss: 0.0243 - val_wine_quality_root_mean_squared_error: 0.5859 - val_wine_type_accuracy: 0.9970
# Epoch 154/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2815 - wine_quality_loss: 0.2609 - wine_type_loss: 0.0206 - wine_quality_root_mean_squared_error: 0.5108 - wine_type_accuracy: 0.9960 - val_loss: 0.3651 - val_wine_quality_loss: 0.3409 - val_wine_type_loss: 0.0242 - val_wine_quality_root_mean_squared_error: 0.5839 - val_wine_type_accuracy: 0.9970
# Epoch 155/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2826 - wine_quality_loss: 0.2631 - wine_type_loss: 0.0195 - wine_quality_root_mean_squared_error: 0.5129 - wine_type_accuracy: 0.9969 - val_loss: 0.3710 - val_wine_quality_loss: 0.3469 - val_wine_type_loss: 0.0241 - val_wine_quality_root_mean_squared_error: 0.5890 - val_wine_type_accuracy: 0.9970
# Epoch 156/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2701 - wine_quality_loss: 0.2585 - wine_type_loss: 0.0116 - wine_quality_root_mean_squared_error: 0.5084 - wine_type_accuracy: 0.9981 - val_loss: 0.3696 - val_wine_quality_loss: 0.3455 - val_wine_type_loss: 0.0241 - val_wine_quality_root_mean_squared_error: 0.5878 - val_wine_type_accuracy: 0.9970
# Epoch 157/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2765 - wine_quality_loss: 0.2625 - wine_type_loss: 0.0140 - wine_quality_root_mean_squared_error: 0.5123 - wine_type_accuracy: 0.9972 - val_loss: 0.3818 - val_wine_quality_loss: 0.3578 - val_wine_type_loss: 0.0240 - val_wine_quality_root_mean_squared_error: 0.5982 - val_wine_type_accuracy: 0.9970
# Epoch 158/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2757 - wine_quality_loss: 0.2583 - wine_type_loss: 0.0174 - wine_quality_root_mean_squared_error: 0.5082 - wine_type_accuracy: 0.9975 - val_loss: 0.3663 - val_wine_quality_loss: 0.3424 - val_wine_type_loss: 0.0239 - val_wine_quality_root_mean_squared_error: 0.5851 - val_wine_type_accuracy: 0.9970
# Epoch 159/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2722 - wine_quality_loss: 0.2601 - wine_type_loss: 0.0120 - wine_quality_root_mean_squared_error: 0.5099 - wine_type_accuracy: 0.9979 - val_loss: 0.3639 - val_wine_quality_loss: 0.3399 - val_wine_type_loss: 0.0239 - val_wine_quality_root_mean_squared_error: 0.5830 - val_wine_type_accuracy: 0.9970
# Epoch 160/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2931 - wine_quality_loss: 0.2750 - wine_type_loss: 0.0181 - wine_quality_root_mean_squared_error: 0.5243 - wine_type_accuracy: 0.9962 - val_loss: 0.3614 - val_wine_quality_loss: 0.3375 - val_wine_type_loss: 0.0239 - val_wine_quality_root_mean_squared_error: 0.5810 - val_wine_type_accuracy: 0.9970
# Epoch 161/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2870 - wine_quality_loss: 0.2654 - wine_type_loss: 0.0216 - wine_quality_root_mean_squared_error: 0.5150 - wine_type_accuracy: 0.9955 - val_loss: 0.3659 - val_wine_quality_loss: 0.3421 - val_wine_type_loss: 0.0239 - val_wine_quality_root_mean_squared_error: 0.5849 - val_wine_type_accuracy: 0.9970
# Epoch 162/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2813 - wine_quality_loss: 0.2643 - wine_type_loss: 0.0169 - wine_quality_root_mean_squared_error: 0.5141 - wine_type_accuracy: 0.9971 - val_loss: 0.3660 - val_wine_quality_loss: 0.3422 - val_wine_type_loss: 0.0238 - val_wine_quality_root_mean_squared_error: 0.5850 - val_wine_type_accuracy: 0.9970
# Epoch 163/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2721 - wine_quality_loss: 0.2566 - wine_type_loss: 0.0154 - wine_quality_root_mean_squared_error: 0.5064 - wine_type_accuracy: 0.9971 - val_loss: 0.3727 - val_wine_quality_loss: 0.3489 - val_wine_type_loss: 0.0238 - val_wine_quality_root_mean_squared_error: 0.5906 - val_wine_type_accuracy: 0.9970
# Epoch 164/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2787 - wine_quality_loss: 0.2596 - wine_type_loss: 0.0191 - wine_quality_root_mean_squared_error: 0.5095 - wine_type_accuracy: 0.9960 - val_loss: 0.3714 - val_wine_quality_loss: 0.3476 - val_wine_type_loss: 0.0238 - val_wine_quality_root_mean_squared_error: 0.5896 - val_wine_type_accuracy: 0.9970
# Epoch 165/180
# 99/99 [==============================] - 0s 4ms/step - loss: 0.2830 - wine_quality_loss: 0.2625 - wine_type_loss: 0.0205 - wine_quality_root_mean_squared_error: 0.5123 - wine_type_accuracy: 0.9963 - val_loss: 0.3664 - val_wine_quality_loss: 0.3427 - val_wine_type_loss: 0.0237 - val_wine_quality_root_mean_squared_error: 0.5854 - val_wine_type_accuracy: 0.9970
# Epoch 166/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2843 - wine_quality_loss: 0.2679 - wine_type_loss: 0.0164 - wine_quality_root_mean_squared_error: 0.5174 - wine_type_accuracy: 0.9970 - val_loss: 0.3646 - val_wine_quality_loss: 0.3410 - val_wine_type_loss: 0.0236 - val_wine_quality_root_mean_squared_error: 0.5839 - val_wine_type_accuracy: 0.9970
# Epoch 167/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2806 - wine_quality_loss: 0.2618 - wine_type_loss: 0.0188 - wine_quality_root_mean_squared_error: 0.5116 - wine_type_accuracy: 0.9963 - val_loss: 0.3724 - val_wine_quality_loss: 0.3488 - val_wine_type_loss: 0.0236 - val_wine_quality_root_mean_squared_error: 0.5906 - val_wine_type_accuracy: 0.9970
# Epoch 168/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2857 - wine_quality_loss: 0.2640 - wine_type_loss: 0.0216 - wine_quality_root_mean_squared_error: 0.5138 - wine_type_accuracy: 0.9964 - val_loss: 0.3683 - val_wine_quality_loss: 0.3447 - val_wine_type_loss: 0.0235 - val_wine_quality_root_mean_squared_error: 0.5871 - val_wine_type_accuracy: 0.9970
# Epoch 169/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2760 - wine_quality_loss: 0.2561 - wine_type_loss: 0.0199 - wine_quality_root_mean_squared_error: 0.5060 - wine_type_accuracy: 0.9957 - val_loss: 0.3654 - val_wine_quality_loss: 0.3419 - val_wine_type_loss: 0.0235 - val_wine_quality_root_mean_squared_error: 0.5847 - val_wine_type_accuracy: 0.9970
# Epoch 170/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2599 - wine_quality_loss: 0.2420 - wine_type_loss: 0.0179 - wine_quality_root_mean_squared_error: 0.4917 - wine_type_accuracy: 0.9967 - val_loss: 0.3654 - val_wine_quality_loss: 0.3419 - val_wine_type_loss: 0.0235 - val_wine_quality_root_mean_squared_error: 0.5847 - val_wine_type_accuracy: 0.9970
# Epoch 171/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2621 - wine_quality_loss: 0.2493 - wine_type_loss: 0.0128 - wine_quality_root_mean_squared_error: 0.4991 - wine_type_accuracy: 0.9978 - val_loss: 0.3676 - val_wine_quality_loss: 0.3441 - val_wine_type_loss: 0.0235 - val_wine_quality_root_mean_squared_error: 0.5866 - val_wine_type_accuracy: 0.9970
# Epoch 172/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2767 - wine_quality_loss: 0.2549 - wine_type_loss: 0.0218 - wine_quality_root_mean_squared_error: 0.5046 - wine_type_accuracy: 0.9946 - val_loss: 0.3658 - val_wine_quality_loss: 0.3424 - val_wine_type_loss: 0.0234 - val_wine_quality_root_mean_squared_error: 0.5851 - val_wine_type_accuracy: 0.9970
# Epoch 173/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2685 - wine_quality_loss: 0.2538 - wine_type_loss: 0.0148 - wine_quality_root_mean_squared_error: 0.5037 - wine_type_accuracy: 0.9977 - val_loss: 0.3647 - val_wine_quality_loss: 0.3413 - val_wine_type_loss: 0.0234 - val_wine_quality_root_mean_squared_error: 0.5842 - val_wine_type_accuracy: 0.9970
# Epoch 174/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2736 - wine_quality_loss: 0.2611 - wine_type_loss: 0.0124 - wine_quality_root_mean_squared_error: 0.5109 - wine_type_accuracy: 0.9975 - val_loss: 0.3718 - val_wine_quality_loss: 0.3485 - val_wine_type_loss: 0.0233 - val_wine_quality_root_mean_squared_error: 0.5903 - val_wine_type_accuracy: 0.9970
# Epoch 175/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2685 - wine_quality_loss: 0.2498 - wine_type_loss: 0.0187 - wine_quality_root_mean_squared_error: 0.4997 - wine_type_accuracy: 0.9961 - val_loss: 0.3683 - val_wine_quality_loss: 0.3451 - val_wine_type_loss: 0.0232 - val_wine_quality_root_mean_squared_error: 0.5875 - val_wine_type_accuracy: 0.9970
# Epoch 176/180
# 99/99 [==============================] - 0s 2ms/step - loss: 0.2745 - wine_quality_loss: 0.2642 - wine_type_loss: 0.0103 - wine_quality_root_mean_squared_error: 0.5139 - wine_type_accuracy: 0.9980 - val_loss: 0.3651 - val_wine_quality_loss: 0.3419 - val_wine_type_loss: 0.0232 - val_wine_quality_root_mean_squared_error: 0.5847 - val_wine_type_accuracy: 0.9970
# Epoch 177/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2793 - wine_quality_loss: 0.2578 - wine_type_loss: 0.0215 - wine_quality_root_mean_squared_error: 0.5076 - wine_type_accuracy: 0.9962 - val_loss: 0.3647 - val_wine_quality_loss: 0.3415 - val_wine_type_loss: 0.0232 - val_wine_quality_root_mean_squared_error: 0.5844 - val_wine_type_accuracy: 0.9970
# Epoch 178/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2727 - wine_quality_loss: 0.2604 - wine_type_loss: 0.0122 - wine_quality_root_mean_squared_error: 0.5099 - wine_type_accuracy: 0.9972 - val_loss: 0.3691 - val_wine_quality_loss: 0.3459 - val_wine_type_loss: 0.0232 - val_wine_quality_root_mean_squared_error: 0.5882 - val_wine_type_accuracy: 0.9970
# Epoch 179/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2673 - wine_quality_loss: 0.2545 - wine_type_loss: 0.0128 - wine_quality_root_mean_squared_error: 0.5044 - wine_type_accuracy: 0.9967 - val_loss: 0.3652 - val_wine_quality_loss: 0.3421 - val_wine_type_loss: 0.0232 - val_wine_quality_root_mean_squared_error: 0.5849 - val_wine_type_accuracy: 0.9970
# Epoch 180/180
# 99/99 [==============================] - 0s 3ms/step - loss: 0.2612 - wine_quality_loss: 0.2492 - wine_type_loss: 0.0120 - wine_quality_root_mean_squared_error: 0.4990 - wine_type_accuracy: 0.9977 - val_loss: 0.3700 - val_wine_quality_loss: 0.3469 - val_wine_type_loss: 0.0231 - val_wine_quality_root_mean_squared_error: 0.5890 - val_wine_type_accuracy: 0.9970

# %%
# Gather the training metrics
loss, wine_quality_loss, wine_type_loss, wine_quality_rmse, wine_type_accuracy = model.evaluate(x=norm_val_X, y=val_Y)

print()
print(f'loss: {loss}')
print(f'wine_quality_loss: {wine_quality_loss}')
print(f'wine_type_loss: {wine_type_loss}')
print(f'wine_quality_rmse: {wine_quality_rmse}')
print(f'wine_type_accuracy: {wine_type_accuracy}')
# Out:
# 25/25 [==============================] - 0s 1ms/step - loss: 0.3381 - wine_quality_loss: 0.3132 - wine_type_loss: 0.0249 - wine_quality_root_mean_squared_error: 0.5596 - wine_type_accuracy: 0.9962
#
# loss: 0.3380642831325531
# wine_quality_loss: 0.3131885528564453
# wine_type_loss: 0.024875735864043236
# wine_quality_rmse: 0.5596325397491455
# wine_type_accuracy: 0.9961977005004883

# %%
predictions = model.predict(norm_test_X)
quality_pred = predictions[0]
type_pred = predictions[1]

# %%
def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0,ylim)
    plt.plot(history.history[metric_name],color='blue',label=metric_name)
    plt.plot(history.history['val_' + metric_name],color='green',label='val_' + metric_name)

# %%
def plot_confusion_matrix(y_true, y_pred, title='', labels=[0,1]):
    cm = confusion_matrix(y_true, y_pred)
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(cm)
    plt.title('Confusion matrix of the classifier')
    fig.colorbar(cax)
    ax.set_xticklabels([''] + labels)
    ax.set_yticklabels([''] + labels)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
          plt.text(j, i, format(cm[i, j], fmt),
                  horizontalalignment="center",
                  color="black" if cm[i, j] > thresh else "white")
    plt.show()

# %%
def plot_diff(y_true, y_pred, title = '' ):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.plot([-100, 100], [-100, 100])
    return plt

# %%
plot_metrics('wine_quality_root_mean_squared_error', 'RMSE', ylim=2)

# %%
plot_metrics('wine_type_loss', 'Wine Type Loss', ylim=0.2)

# %%
plot_confusion_matrix(test_Y[1], np.round(type_pred), title='Wine Type', labels = [0, 1])

# %%
scatter_plot = plot_diff(test_Y[0], quality_pred, title='Type')
